# %%
import numpy as np
import matplotlib.pylab as plt

from rss.client import rssFromS3

# %%
client_kwargs = {'aws_access_key_id':'AKIAQJQE57C5EICVP6GX', 
                    'aws_secret_access_key':'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'}
rss = rssFromS3('geophysics-on-cloud/poseidon/seismic/rss/psdn11_TbsdmF_full_w_AGC_Nov11', client_kwargs)

# %%
rss.query_by_xy(rss.xy[1337,:])
# Out:
# Assembling a tree to map il/xl to x/y.
# This could take a couple of minutes,
# But only happens one time.
# (array([[     0.        , 124990.59964653, 125002.9199659 ,
#          187459.88904296]]),
#  [array([[ 983, 1841],
#          [ 983, 1840],
#          [ 983, 1842],
#          [ 984, 1841]])])

# %%
from time import time
st = time()
inline, mask = rss.line(2000, sort_order='inline')
print ("Elapsed Time : ", time() - st)

plt.figure(figsize=(10,20))
plt.imshow(inline, cmap='gray', aspect=1.5,
           vmin=-2*np.std(inline[~mask]), vmax=2*np.std(inline[~mask]))
plt.show()
# Out:
# Elapsed Time :  0.3979651927947998

# %%
with open('traces.bin', 'rb') as fp:
    traces = np.fromfile(fp, '<f4')
traces.shape = (-1, inline.shape[0])
traces = traces.T
ftraces = np.sqrt(np.mean(np.abs(np.fft.fft(traces, axis=0))**2, axis=1))[:1501//2]

inline, mask = rss.line(2000, sort_order='inline')
finline = np.sqrt(np.mean(np.abs(np.fft.fft(inline, axis=0))**2, axis=1))[:1501//2]

x = 20*np.log(ftraces/ftraces.max())
plt.plot(x)
y = 20*np.log(finline/ftraces.max())
plt.plot(y)

#plt.semilogy(np.abs(ftraces-finline)/ftraces.max(),'-r')
